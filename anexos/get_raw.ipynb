# %% [markdown]
# # Obtener información requerida para el Modelo DuPont

# %%
# Requerimientos
# !pip install selenium pandas sqlalchemy

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import sqlalchemy

db = sqlalchemy.create_engine("sqlite:///data.sqlite")

# %%
# Crear "raw_data"
try:
    raw = pd.read_sql("select * from raw_data", db)
except:
    raw = pd.DataFrame(columns=["Source", "Revenue", "Income", "Assets", "Equity"])
raw
# Out:
# Index(['index', 'Source', 'Revenue', 'Income', 'Assets', 'Equity'], dtype='object')
